# %% [markdown]
# 1. The MickeyMouse problem
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. For numbers which are multiples of both three and five print MickeyMouse
#
# b) Put the result in a tuple and substitute Mickey with Donald and Mouse with Duck

# %%
import numpy as np
import pandas as pd
df8 = pd.read_csv(r"C:\\Users\\TEST\\Desktop\\Project Comp physics\\L8",delimiter='\t')
df8
# Out:
#       T     E_avg     Esq_avg     M_avg    Msq_avg  Mabs_avg          X  \
# 0   0.5 -1.840563  220.315450 -0.680200  45.066825  0.744456   0.000000
# 1   0.6 -1.999975  255.993800 -0.999994  63.999213  0.999994   0.000021
# 2   0.7 -1.999837  255.959700 -0.999959  63.994881  0.999959   0.000116
# 3   0.8 -1.999556  255.890025 -0.999888  63.985838  0.999888   0.000296
# 4   0.9 -1.998900  255.727350 -0.999722  63.964981  0.999722   0.000640
# 5   1.0 -1.996831  255.214825 -0.999194  63.898525  0.999194   0.001683
# 6   1.1 -1.994475  254.633900 -0.998584  63.822069  0.998584   0.002855
# 7   1.2 -1.988475  253.155750 -0.996984  63.621819  0.996984   0.006031
# 8   1.3 -1.979206  250.882225 -0.994494  63.310875  0.994494   0.010565
# 9   1.4 -1.967600  248.066250 -0.991228  62.906544  0.991228   0.017442
# 10  1.5 -1.950650  243.966050 -0.986397  62.310519  0.986397   0.026584
# 11  1.6 -1.930244  239.114925 -0.980309  61.570844  0.980309   0.041519
# ...

# %%
print(mat[10,31])
# Out:
# 1.0

# %%
a = np.array([[1,1],[-1,-1]])
b = (((a*255)+255)/2).astype(int)
print(b)
# Out:
# [[255 255]
#  [  0   0]]

# %%
for i in range(100):
    if (i+1)%3==0 and (i+1)%5==0:
        print("MickeyMouse")
    elif (i+1)%3==0:
        print("Mickey")
    elif (i+1)%5==0:
        print("Mouse")
    else:
        print(str(i+1))
# Out:
# 1
# 2
# Mickey
# 4
# Mouse
# Mickey
# 7
# 8
# Mickey
# Mouse
# 11
# Mickey
# 13
# 14
# MickeyMouse
# 16
# 17
# Mickey
# 19
# Mouse
# Mickey
# 22
# 23
# Mickey
# Mouse
# 26
# Mickey
# 28
# 29
# MickeyMouse
# 31
# 32
# Mickey
# 34
# Mouse
# Mickey
# 37
# 38
# Mickey
# Mouse
# 41
# Mickey
# 43
# 44
# MickeyMouse
# 46
# 47
# Mickey
# 49
# Mouse
# Mickey
# 52
# 53
# Mickey
# Mouse
# 56
# Mickey
# 58
# 59
# MickeyMouse
# 61
# 62
# Mickey
# 64
# Mouse
# Mickey
# 67
# 68
# Mickey
# Mouse
# 71
# Mickey
# 73
# 74
# MickeyMouse
# 76
# 77
# Mickey
# 79
# Mouse
# Mickey
# 82
# 83
# Mickey
# Mouse
# 86
# Mickey
# 88
# 89
# MickeyMouse
# 91
# 92
# Mickey
# 94
# Mouse
# Mickey
# 97
# 98
# Mickey
# Mouse

# %%
cartoonList = []
for i in range(100):
    if (i+1)%3==0 and (i+1)%5==0:
        #print("MickeyMouse")
        cartoonList.append("MickeyMouse")
    elif (i+1)%3==0:
        #print("Mickey")
        cartoonList.append("Mickey")
    elif (i+1)%5==0:
        #print("Mouse")
        cartoonList.append("Mouse")
    else:
        #print(str(i+1))
        cartoonList.append(str(i+1))
MickeyTuple = tuple(cartoonList)
print('\n',MickeyTuple)

for i in range(len(cartoonList)):
    if cartoonList[i]=='Mickey':
        cartoonList[i]="Donald"
    elif cartoonList[i]=="Mouse":
        cartoonList[i]="Duck"
    elif cartoonList[i]=="MickeyMouse":
        cartoonList[i]="DonaldDuck"
print('\n',cartoonList)  
DonaldTuple = tuple(cartoonList) 
print('\n',DonaldTuple)
# Out:
#  ('1', '2', 'Mickey', '4', 'Mouse', 'Mickey', '7', '8', 'Mickey', 'Mouse', '11', 'Mickey', '13', '14', 'MickeyMouse', '16', '17', 'Mickey', '19', 'Mouse', 'Mickey', '22', '23', 'Mickey', 'Mouse', '26', 'Mickey', '28', '29', 'MickeyMouse', '31', '32', 'Mickey', '34', 'Mouse', 'Mickey', '37', '38', 'Mickey', 'Mouse', '41', 'Mickey', '43', '44', 'MickeyMouse', '46', '47', 'Mickey', '49', 'Mouse', 'Mickey', '52', '53', 'Mickey', 'Mouse', '56', 'Mickey', '58', '59', 'MickeyMouse', '61', '62', 'Mickey', '64', 'Mouse', 'Mickey', '67', '68', 'Mickey', 'Mouse', '71', 'Mickey', '73', '74', 'MickeyMouse', '76', '77', 'Mickey', '79', 'Mouse', 'Mickey', '82', '83', 'Mickey', 'Mouse', '86', 'Mickey', '88', '89', 'MickeyMouse', '91', '92', 'Mickey', '94', 'Mouse', 'Mickey', '97', '98', 'Mickey', 'Mouse')
#
# ...

# %% [markdown]
# 2\. The swap function
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
def swap1(x,y):
    temp = x
    x = y
    y = temp
    return(x,y)

def swap2(x,y):
    temp = [x,y]
    temp.reverse()
    return(temp[0],temp[1])

def swap3(x,y):
    return(y,x)

swap1(2,3)
swap2("demon","God")
swap3("God","Goddess")
# Out:
# ('Goddess', 'God')

# %% [markdown]
# 3\. Computing the distance
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %%
from math import sqrt 
u = (3,0)
v = (0,4)

def dist(u,v):
    x1=u[0]
    x2=v[0]
    y1=u[1]
    y2=v[1]
    length = sqrt((x1-x2)**2+(y1-y2)**2)
    return(length)
dist(u,v)
# Out:
# 5.0

# %% [markdown]
# 4\. Counting letters
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
from collections import Counter
string = "I love Laboratory of Computational Physics"
count = Counter(string.lower())
print(count)
# Out:
# Counter({'o': 6, ' ': 5, 'a': 4, 'i': 3, 'l': 3, 't': 3, 'r': 2, 'y': 2, 'c': 2, 'p': 2, 's': 2, 'v': 1, 'e': 1, 'b': 1, 'f': 1, 'm': 1, 'u': 1, 'n': 1, 'h': 1})

# %% [markdown]
# 5\. Isolating the unique
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

from collections import Counter
count = Counter(l)
count = dict(count)#count represents dictionary. Converting formally into a dictionary.
#print(count)
#print(count.items())

uniqueList=[]
for key,value in count.items():
     if value==1:
            uniqueList.append(key)
print("List of Unique numbers: ",uniqueList)
print("Length of Unique list: ",len(uniqueList))
# Out:
# List of Unique numbers:  [58, 74, 96, 64, 10, 24, 19, 33, 86, 99, 18, 47, 88, 55, 54, 8, 79, 81, 57, 37, 1, 9, 95, 90, 98, 39, 16, 82, 92, 41, 30, 94, 5, 72, 87, 75, 53]
# Length of Unique list:  37

# %% [markdown]
# 6\. Combination of functions
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def square(x):
    return(x**2)

def cube(x):
    return(x**3)

def powerSix(x):
    return(square(cube(x)))
powerSix(2)
# Out:
# 64

# %% [markdown]
# 7\. Cubes
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
x=range(11)
cubeX1 = []
for element in x:
    cubeX1.append(element**3)
print(cubeX1)

cubeX2 = [element**3 for element in x]#list comprehension
print(cubeX2)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# 8\. Nested list comprehension
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
"""
PythogoreanTriplets = []
for a in range(1,100):
    for b in range(1,100):
        for c in range(1,100):
            if a**2 + b**2 == c**2:
                PythogoreanTriplets.append((a,b,c))
print(PythogoreanTriplets)
"""
#Just go on writing for loops instruction like above without ":" symbol. 
PythogoreanTriplets = [(a,b,c)for a in range(1,100) for b in range(1,100) for c in range(1,100) if a**2+b**2==c**2]
print(PythogoreanTriplets)
# Out:
# [(3, 4, 5), (4, 3, 5), (5, 12, 13), (6, 8, 10), (7, 24, 25), (8, 6, 10), (8, 15, 17), (9, 12, 15), (9, 40, 41), (10, 24, 26), (11, 60, 61), (12, 5, 13), (12, 9, 15), (12, 16, 20), (12, 35, 37), (13, 84, 85), (14, 48, 50), (15, 8, 17), (15, 20, 25), (15, 36, 39), (16, 12, 20), (16, 30, 34), (16, 63, 65), (18, 24, 30), (18, 80, 82), (20, 15, 25), (20, 21, 29), (20, 48, 52), (21, 20, 29), (21, 28, 35), (21, 72, 75), (24, 7, 25), (24, 10, 26), (24, 18, 30), (24, 32, 40), (24, 45, 51), (24, 70, 74), (25, 60, 65), (27, 36, 45), (28, 21, 35), (28, 45, 53), (30, 16, 34), (30, 40, 50), (30, 72, 78), (32, 24, 40), (32, 60, 68), (33, 44, 55), (33, 56, 65), (35, 12, 37), (35, 84, 91), (36, 15, 39), (36, 27, 45), (36, 48, 60), (36, 77, 85), (39, 52, 65), (39, 80, 89), (40, 9, 41), (40, 30, 50), (40, 42, 58), (40, 75, 85), (42, 40, 58), (42, 56, 70), (44, 33, 55), (45, 24, 51), (45, 28, 53), (45, 60, 75), (48, 14, 50), (48, 20, 52), (48, 36, 60), (48, 55, 73), (48, 64, 80), (51, 68, 85), (52, 39, 
# ...

# %% [markdown]
# 9\. Normalization
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
NumberTuple = (1,2,1)

def normalize(tup):
    squares = [x**2 for x in tup]
    sumSquares = sum(squares)
    normList = [elem/(sumSquares**0.5) for elem in NumberTuple]
    return tuple(normList)

normalize(NumberTuple)
# Out:
# (0.4082482904638631, 0.8164965809277261, 0.4082482904638631)
